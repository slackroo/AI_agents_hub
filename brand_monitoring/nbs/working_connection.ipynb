# %%
import requests

url = "https://api.brightdata.com/request"
brd_test_url = "https://www.google.com/search?q=redbull+drinks+launch+linkedin&tbs=qdr&brd_json=1&num=50"
payload = {
    "zone": 'bright_serp_cpg',
    "url": brd_test_url,
    "format": "json",
    "method": "GET",
    # "country": "IN"
}
headers = {
    "Authorization": "Bearer d3b76ac1a1eaf4c1797f8c1e8d4f505d09cb447603367f99e033cf8936e0255b",
    "Content-Type": "application/json"
}

response = requests.request("POST", url, json=payload, headers=headers)

body_data = response.json().get('body', '')  # Get the body content

# If body_data is a string containing JSON, we need to parse it
import json
if isinstance(body_data, str):
    try:
        parsed_data = json.loads(body_data)
        news_data = parsed_data.get('organic', [])
        print(json.dumps(news_data, indent=2))  # Pretty print the news data
    except json.JSONDecodeError as e:
        print(f"Error parsing JSON: {e}")
# Out:
# [
#   {
#     "link": "https://www.linkedin.com/posts/aonetti_energy-drinks-company-red-bull-launches-investment-activity-7318868419372601344-hS7Q",
#     "display_link": "10+ reactions \u00b7 7 hours ago",
#     "title": "Energy drinks company Red Bull launches investment unit",
#     "description": "Red Bull Gets Its Wings in CVC Energy drink company Red Bull has launched a CVC arm, Red Bull Ventures. The CVC unit will make early-stage ...",
#     "rank": 1,
#     "global_rank": 1
#   },
#   {
#     "link": "https://www.linkedin.com/company/red-bull",
#     "display_link": "1.8M+ followers",
#     "title": "Red Bull",
#     "description": "Website: http://www.redbull.com/jobs. External link for Red Bull ; Industry: Food and Beverage Services ; Company size: 10,001+ employees ; Headquarters: Fuschl.",
#     "extensions": [
#       {
#         "type": "site_link",
#         "text": "Overview",
#         "link": "https://uk.linkedin.com/company/red-bull",
#         "rank": 1
#       },
#       {
#         "type": "site_link",
#         "text": "Jobs",
#         "link": "https://www.linkedin.com/company/red-bull/jobs",
#         "rank": 2
#       },
#       {
#         "type": "site_link",
#         "text": "Life",
#         "link": "https://www.linkedin.com/company/red-bull/life",
#         "rank": 3
#       },
#       {
#         "type": "site_link",
#         "text": "Food and Beverage Services",
#         "link": "https://au.linkedin.com/company/red-bull",
#         "rank": 4
#       },
#       {
#         "type": "missing",
#         "text": "launch",
#         "rank": 5
#       },
#       {
#         "type": "must_include",
#         "text": "launch",
#         "link": "https://www.google.com/search?num=50&sca_esv=ec1c0fa4563bd641&gl=us&hl=en&q=redbull+drinks+%22launch%22+linkedin&sa=X&ved=2ahUKEwjXnfSCzOGMAxWGLkQIHXmwOzYQ5t4CegQIKBAB",
#         "rank": 6
#       }
#     ],
#     "rank": 2,
#     "global_rank": 2
#   },
#   {
#     "link": "https://www.linkedin.com/posts/johnpkelly2_red-bull-broadens-sugar-free-offering-with-activity-7291411322200600576-qhRD",
#     "display_link": "30+ reactions \u00b7 2 months ago",
#     "title": "John Kelly's Post",
#     "description": "Red Bull has announced the global launch of Red Bull Zero, a zero-sugar and zero-calorie version of its classic Red Bull Original energy drink.",
#     "rank": 3,
#     "global_rank": 3
#   },
#   {
#     "link": "https://hr.linkedin.com/company/red-bull?trk=public_profile_experience-group-header",
#     "display_link": "1.8M+ followers",
#     "title": "Red Bull",
#     "description": "... Red Bull \u2013 jobs.redbull.com. Website: http://www.redbull.com/jobs. External link for Red Bull. Industry: Food and Beverage Services. Company size: 10,001+ ...",
#     "extensions": [
#       {
#         "type": "missing",
#         "text": "drinks",
#         "rank": 1
#       },
#       {
#         "type": "missing",
#         "text": "launch",
#         "rank": 2
#       }
#     ],
#     "rank": 4,
#     "global_rank": 4
#   },
#   {
#     "link": "https://www.linkedin.com/company/redbulldistributioncompany",
#     "display_link": "28.7K+ followers",
#     "title": "Red Bull Distribution Company",
#     "description": "Discover your next opportunity at: jobs.redbull.com. Website: https://redbulldistributioncompany.com. External link for Red Bull Distribution Company. Industry ...",
#     "extensions": [
#       {
#         "type": "missing",
#         "text": "launch",
#         "rank": 1
#       },
#       {
#         "type": "must_include",
#         "text": "launch",
#         "link": "https://www.google.com/search?num=50&sca_esv=ec1c0fa4563bd641&gl=us&hl=en&q=redbull+drinks+%22launch%22+linkedin&sa=X&ved=2ahUKEwjXnfSCzOGMAxWGLkQIHXmwOzYQ5t4CegQIJxAB",
#         "rank": 2
#       }
#     ],
#     "rank": 5,
#     "global_rank": 5
#   },
#   {
#     "link": "https://bw.linkedin.com/company/red-bull",
#     "display_link": "1.8M+ followers",
#     "title": "Red Bull",
#     "description": "Website: http://www.redbull.com/jobs. External link for Red Bull ; Industry: Food and Beverage Services ; Company size: 10,001+ employees ; Headquarters: Fuschl.",
#     "extensions": [
#       {
#         "type": "missing",
#         "text": "drinks",
#         "rank": 1
#       },
#       {
#         "type": "missing",
#         "text": "launch",
#         "rank": 2
#       }
#     ],
#     "rank": 6,
#     "global_rank": 6
#   },
#   {
#     "link": "https://www.linkedin.com/in/rsamanthareyes",
#     "display_link": "930+ followers",
#     "title": "Samantha Reyes - Beverage Initiatives Manager - Red Bull",
#     "description": "Brand Marketing at Red Bull \u00b7 With a wide range of experiences spanning entertainment, education, consumer goods, and healthcare, I have used my innate ...",
#     "rank": 7,
#     "global_rank": 7
#   },
#   {
#     "link": "https://www.linkedin.com/in/philipp-hausmaninger-6017a156",
#     "display_link": "1.1K+ followers",
#     "title": "Philipp Hausmaninger - Red Bull",
#     "description": "Websites. Company Website: http://redbull.com.",
#     "rank": 8,
#     "global_rank": 8
#   },
#   {
#     "link": "https://www.linkedin.com/posts/louis-pelliccia_want-to-build-the-next-red-bull-coca-cola-activity-7293311712567443456-Ptao",
#     "display_link": "1 reaction \u00b7 2 months ago",
#     "title": "Want to build the next Red Bull, Coca-Cola, or Monster? It's ...",
#     "description": "Want to build the next Red Bull, Coca-Cola, or Monster? It's not just about a great-tasting drink\u2014it's about strategy, execution, and a bit of ...",
#     "rank": 9,
#     "global_rank": 9
#   },
#   {
#     "link": "https://www.reddit.com/r/advertising/comments/ln90s/one_of_red_bulls_schemes_find_interns_at/",
#     "display_link": "5 comments \u00b7 13 years ago",
#     "title": "One of Red Bull's schemes: Find interns at influential digital ...",
#     "description": "One of Red Bull's schemes: Find interns at influential digital agencies on LinkedIn, send them free drinks. ... cool, redbull are pioneers of real ...",
#     "rank": 10,
#     "global_rank": 10
#   },
#   {
#     "link": "https://www.linkedin.com/posts/shankar-bhalla_sting-redbull-marketing-activity-7284555323850289152-v6JR",
#     "display_link": "400+ reactions \u00b7 3 months ago",
#     "title": "sting #redbull #marketing #india #business | Shankar Bhalla",
#     "description": "... redbull #marketing #india #business | 33 comments on LinkedIn. ... Sting is beating the shit out of energy drinks like Red Bull and Monster Energy ...",
#     "rank": 11,
#     "global_rank": 11
#   },
#   {
#     "link": "https://www.campaignlive.co.uk/article/ex-red-bull-chief-rivals-brand-energy-drink-launch/1375921",
#     "display_link": "https://www.campaignlive.co.uk \u203a article \u203a ex-red-bull-...",
#     "title": "Ex-Red Bull chief rivals brand with energy drink launch",
#     "description": "Ex-Red Bull marketer Huib van Bockel has launched an energy drink to rival his former employer - and it's made with half the sugar.",
#     "extensions": [
#       {
#         "inline": true,
#         "type": "text",
#         "text": "Dec 7, 2015",
#         "rank": 1
#       }
#     ],
#     "rank": 12,
#     "global_rank": 12
#   },
#   {
#     "link": "https://www.linkedin.com/in/chad-lemeur-a3060b73",
#     "display_link": "2.7K+ followers",
#     "title": "Chad LeMeur - Red Bull",
#     "description": "It Can be done. \u00b7 Experience: Red Bull \u00b7 Education: University of Arkansas at Fayetteville \u00b7 Location: Miami-Fort Lauderdale Area \u00b7 500+ connections on ...",
#     "rank": 13,
#     "global_rank": 13
#   },
#   {
#     "link": "https://www.linkedin.com/posts/rounak-kumar-gunjan-28883212b_red-bull-is-the-energy-drink-of-the-world-activity-7200767213706895361-jwli",
#     "display_link": "9 reactions \u00b7 10 months ago",
#     "title": "Rounak Kumar Gunjan's Post",
#     "description": "Energy Drink Market : \u00b7 World's first energy drink launched in 1987 was Red Bull. ... Red Bull and regular soft drinks. #Sting #RedBull ...",
#     "rank": 14,
#     "global_rank": 14
#   },
#   {
#     "link": "https://en.wikipedia.org/wiki/Red_Bull",
#     "display_link": "https://en.wikipedia.org \u203a wiki \u203a Red_Bull",
#     "title": "Red Bull",
#     "description": "Since its launch in 1987, more than 100 billion cans of Red Bull have been sold worldwide, including over 12.6 billion in 2024. Red Bull Energy Drink ...",
#     "rank": 15,
#     "global_rank": 15
#   },
#   {
#     "link": "https://be.linkedin.com/company/red-bull?trk=ppro_cprof",
#     "display_link": "1.8M+ followers",
#     "title": "Red Bull",
#     "description": "Website: http://www.redbull.com/jobs. External link for Red Bull ; Industry: Food and Beverage Services ; Company size: 10,001+ employees ; Headquarters: Fuschl.",
#     "extensions": [
#       {
#         "type": "missing",
#         "text": "drinks",
#         "rank": 1
#       },
#       {
#         "type": "missing",
#         "text": "launch",
#         "rank": 2
#       }
#     ],
#     "rank": 16,
#     "global_rank": 16
#   },
#   {
#     "link": "https://www.motorsport.com/f1/news/red-bull-horner-allegations-investigation/10572594/",
#     "display_link": "https://www.motorsport.com \u203a news \u203a red-bull-horner-a...",
#     "title": "Red Bull launches investigation following F1 boss Horner ...",
#     "description": "Red Bull says it has launched an independent investigation into allegations against its Formula 1 team's boss Christian Horner.",
#     "extensions": [
#       {
#         "inline": true,
#         "type": "text",
#         "text": "Feb 5, 2024",
#         "rank": 1
#       }
#     ],
#     "rank": 17,
#     "global_rank": 17
#   },
#   {
#     "link": "https://financialpost.com/pmn/business-pmn/the-energy-drink-that-hooked-young-women-and-industry-giant-celsius",
#     "display_link": "https://financialpost.com \u203a pmn \u203a business-pmn \u203a the-e...",
#     "title": "The Energy Drink That Hooked Young Women",
#     "description": "Alani Nu moved away from the male-focused vibe of Red Bull and Monster with colorful packaging, fruity flavors, being sugar-free, and health ...",
#     "extensions": [
#       {
#         "inline": true,
#         "type": "text",
#         "text": "3 days ago",
#         "rank": 1
#       }
#     ],
#     "rank": 18,
#     "global_rank": 18
#   },
#   {
#     "link": "https://www.linkedin.com/posts/samuelkeene_today-we-launch-juvee-a-rejuvenating-energy-activity-6983110299012804608-oUXP",
#     "display_link": "590+ reactions \u00b7 2 years ago",
#     "title": "Samuel Keene - Today, we launch Juvee",
#     "description": "Today, we launch Juvee; a rejuvenating energy drink. Never in my ... Red Bull and I signed him as one of our competitive players. It's ...",
#     "rank": 19,
#     "global_rank": 19
#   },
#   {
#     "link": "https://www.scooterscoffee.com/menu/limited-time",
#     "display_link": "https://www.scooterscoffee.com \u203a menu \u203a limited-time",
#     "title": "Limited Time Menu",
#     "description": "Limited Time ; Strawberry Blossom Matcha ; Strawberry Blossom Red Bull Infusion ; Peach Bliss Quencher ; Cinnamon Brown Sugar Oatmilk Latte Blender.",
#     "rank": 20,
#     "global_rank": 20
#   },
#   {
#     "link": "https://www.instagram.com/reel/DIlnzBIi6v5/",
#     "display_link": "10+ likes \u00b7 5 minutes ago",
#     "title": "Entrepreneur | Emma Chamberlain turned a coffee obsession ...",
#     "description": "Emma makes some key moves fast. One, she hires a former Red Bull exec to be her CEO. Two, she makes the coffee USDA organic certified and three, ...",
#     "image": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRQY4CO7FVHS4AizC6dnGZ8te9grvKGPTnGcuBuuXAr5rVg&s",
#     "image_url": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRQY4CO7FVHS4AizC6dnGZ8te9grvKGPTnGcuBuuXAr5rVg&s",
#     "duration": "0:59",
#     "duration_sec": 59,
#     "rank": 21,
#     "global_rank": 21
#   },
#   {
#     "link": "https://www.globenewswire.com/news-release/2025/04/17/3063696/0/en/BROAD-ARROW-PRESENTS-DARIO-FRANCHITTI-MEMORABILIA-IN-ONLINE-AUCTION-TO-BENEFIT-SIR-JACKIE-STEWART-S-RACE-AGAINST-DEMENTIA-CHARITY.html",
#     "display_link": "https://www.globenewswire.com \u203a 2025/04/17 \u203a BROAD...",
#     "title": "BROAD ARROW PRESENTS DARIO FRANCHITTI ...",
#     "description": "The visor is signed with a rare early version of Mika's autograph and inscripted 'The Finn 92'. Lot 213: Sebastian Vettel 2011 Original Red Bull ...",
#     "extensions": [
#       {
#         "inline": true,
#         "type": "text",
#         "text": "20 hours ago",
#         "rank": 1
#       }
#     ],
#     "rank": 22,
#     "global_rank": 25
#   },
#   {
#     "link": "https://www.precedenceresearch.com/press-release/functional-beverages-market",
#     "display_link": "https://www.precedenceresearch.com \u203a press-release \u203a fu...",
#     "title": "Functional Beverages Market Revenue to Attain USD ...",
#     "description": "Functional Beverages Market Top Companies. PepsiCo Inc. The Coca-Cola Company; Kraft Heinz Company; Nestle S.A; Red Bull GmbH; The Hain ...",
#     "extensions": [
#       {
#         "inline": true,
#         "type": "text",
#         "text": "3 days ago",
#         "rank": 1
#       }
#     ],
#     "rank": 23,
#     "global_rank": 26
#   },
#   {
#     "link": "https://www.sportcal.com/news/news-wrap-minnesota-wild-valencia-toronto-tempo-red-bull/",
#     "display_link": "https://www.sportcal.com \u203a news \u203a news-wrap-minnesot...",
#     "title": "Minnesota Wild, Valencia, Toronto Tempo, Red Bull",
#     "description": "Patr\u00f3n became the first-ever spirits partner of the Red Bull team in 2023, which involved a Patr\u00f3n Tequila bar featuring in the Red Bull Energy ...",
#     "extensions": [
#       {
#         "inline": true,
#         "type": "text",
#         "text": "2 days ago",
#         "rank": 1
#       }
#     ],
#     "rank": 24,
#     "global_rank": 27
#   },
#   {
#     "link": "https://beincrypto.com/gate-io-oracle-red-bull-racing-f1/",
#     "display_link": "https://beincrypto.com \u203a Press Releases",
#     "title": "Gate.io x Oracle Red Bull Racing in F1",
#     "description": "In an even bolder move, it has partnered with the world-renowned Oracle Red Bull Racing in F1, marking a major milestone in its global cross ...",
#     "extensions": [
#       {
#         "inline": true,
#         "type": "text",
#         "text": "3 hours ago",
#         "rank": 1
#       }
#     ],
#     "rank": 25,
#     "global_rank": 28
#   },
#   {
#     "link": "https://www.admiralbeverage.com/",
#     "display_link": "https://www.admiralbeverage.com",
#     "title": "Admiral Beverage Corporation | Over 50 Years of Beverage ...",
#     "description": "Admiral Beverage \u00b7 Novamex \u00b7 Polar Beverage \u00b7 Country Time Lemonade \u00b7 Fiji \u00b7 Hog Wash \u00b7 Red Bull \u00b7 Alcoholic Partners \u00b7 Brands \u00b7 Blog \u00b7 Careers \u00b7 Contact Us.",
#     "rank": 26,
#     "global_rank": 29
#   },
#   {
#     "link": "https://www.linkedin.com/company/redbullmediahouse",
#     "display_link": "115.6K+ followers",
#     "title": "Red Bull Media House",
#     "description": "About us ; Website: http://www.redbullmediahouse.com. External link for Red Bull Media House ; Industry: Media Production ; Company size: 1,001-5,000 employees.",
#     "rank": 27,
#     "global_rank": 30
#   },
#   {
#     "link": "https://www.essence.com/fashion/icymi-coach-wnba-partnership/",
#     "display_link": "https://www.essence.com \u203a fashion \u203a icymi-coach-wnba...",
#     "title": "ICYMI: Coach Announces Multi-Year Partnership With WNBA ...",
#     "description": "Notably, Level 1 delivered a \u201cfirst taste\u201d of the Nobu Omakase experience, which was paired with a curated Red Bull cocktail menu. ... The launch ...",
#     "extensions": [
#       {
#         "inline": true,
#         "type": "text",
#         "text": "4 days ago",
#         "rank": 1
#       }
#     ],
#     "rank": 28,
#     "global_rank": 31
#   },
#   {
#     "link": "https://www.f1lasvegasgp.com/",
#     "display_link": "https://www.f1lasvegasgp.com",
#     "title": "Official site of the Formula 1 Las Vegas Grand Prix",
#     "description": "Red Bull logo. Sphere logo. T-Mobile logo. Venetian logo. Event Partners. Aggreko ... Linkedin Follow Us On Youtube. 2025 Formula One World Championship ...",
#     "rank": 29,
#     "global_rank": 32
#   },
#   {
#     "link": "https://www.motorsport.com/f1/news/heres-why-legos-red-bull-kits-are-the-only-18-plus-f1-speed-champions-sets/10713914/",
#     "display_link": "https://www.motorsport.com \u203a news \u203a heres-why-legos-...",
#     "title": "Why Lego's Red Bull kits are the only aged 18+ F1 Speed ...",
#     "description": "Europe has even stricter regulations that mean drinks like Red Bull and Monster, which sponsors McLaren, can't be sold to anyone under the age ...",
#     "extensions": [
#       {
#         "inline": true,
#         "type": "text",
#         "text": "2 days ago",
#         "rank": 1
#       }
#     ],
#     "rank": 30,
#     "global_rank": 33
#   },
#   {
#     "link": "https://www.myspinx.com/",
#     "display_link": "https://www.myspinx.com",
#     "title": "Spinx | Making Life Easier in SC",
#     "description": "Spinx Convenience Stores across South Carolina offer customers delicious food, high-quality fuels, and cost-saving Spinx Xtras offers.",
#     "rank": 31,
#     "global_rank": 34
#   },
#   {
#     "link": "https://www.nrn.com/quick-service/scooter-s-coffee-redesigns-rewards-program",
#     "display_link": "https://www.nrn.com \u203a Quick Service",
#     "title": "Scooter's Coffee redesigns rewards program",
#     "description": "Customers can redeem Smiles for food items, drink modifiers like cold foam, extra espresso shots, and cans of Red Bull. In the new Scooter's Coffee rewards ...",
#     "rank": 32,
#     "global_rank": 35
#   },
#   {
#     "link": "https://www.betterretailing.com/booker-sales-drop-amid-focus-on-value/",
#     "display_link": "https://www.betterretailing.com \u203a booker-sales-drop-am...",
#     "title": "Booker sales drop amid focus on value",
#     "description": "EXCLUSIVE: Red Bull and Booker silent on price hikes amid sugar tax rises. \u201cIn retail, we're seeing more people joining our 'banner' brands ...",
#     "extensions": [
#       {
#         "inline": true,
#         "type": "text",
#         "text": "4 hours ago",
#         "rank": 1
#       }
#     ],
#     "rank": 33,
#     "global_rank": 36
#   },
#   {
#     "link": "https://www.instagram.com/reel/DIkRkGdNJMY/",
#     "display_link": "4 likes \u00b7 12 hours ago",
#     "title": "The Real Housewives of Austin \ud83e\udea9 | on this episode of the ...",
#     "description": "you're holding a lukewarm vodka red bull, trying to explain to your friend why texting your ex at 1:12 a.m. is technically a form of closure.",
#     "image": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSfJhPTznpRqC3IrC2eRVfDTOsCwcoYUgCwGVsb7Gp2YGbb&s",
#     "image_url": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSfJhPTznpRqC3IrC2eRVfDTOsCwcoYUgCwGVsb7Gp2YGbb&s",
#     "duration": "0:27",
#     "duration_sec": 27,
#     "rank": 34,
#     "global_rank": 37
#   },
#   {
#     "link": "https://www.restaurantdive.com/news/scooters-coffee-2025-loyalt-points-smiles-update/745417/",
#     "display_link": "https://www.restaurantdive.com \u203a news \u203a scooters-coffe...",
#     "title": "Scooter's Coffee switches to points-based loyalty",
#     "description": "... drink modifiers like cold foam and extra espresso shots, and cans of Red Bull,\u201d for the first time. The program also awards badges and ...",
#     "extensions": [
#       {
#         "inline": true,
#         "type": "text",
#         "text": "3 days ago",
#         "rank": 1
#       }
#     ],
#     "rank": 35,
#     "global_rank": 38
#   },
#   {
#     "link": "https://thebambooworks.com/th-international-tastes-success-with-bagels-in-donut-averse-china/",
#     "display_link": "https://thebambooworks.com \u203a th-international-tastes-su...",
#     "title": "TH International tastes success with bagels in donut- ...",
#     "description": "Red Bull slayer Eastroc chases Hong Kong IPO to boost global charge. 605499.SHG. April 11, 2025. Uxin gets new cash injection as its used car ...",
#     "extensions": [
#       {
#         "inline": true,
#         "type": "text",
#         "text": "8 hours ago",
#         "rank": 1
#       }
#     ],
#     "rank": 36,
#     "global_rank": 39
#   },
#   {
#     "link": "https://www.nwitimes.com/news/local/article_85426b20-0a3d-405b-b46f-f680bf036b16.html",
#     "display_link": "https://www.nwitimes.com \u203a news \u203a local",
#     "title": "Webb Auto Group breaks ground on new Schererville ...",
#     "description": "LinkedIn \u00b7 YouTube \u00b7 Instagram ... The Michigan-based chain serves coffee, lattes, tea lattes, Red Bull mocktails hot chocolates and freezes.",
#     "extensions": [
#       {
#         "inline": true,
#         "type": "text",
#         "text": "14 hours ago",
#         "rank": 1
#       }
#     ],
#     "rank": 37,
#     "global_rank": 40
#   },
#   {
#     "link": "https://www.billboard.com/lists/revolve-festival-2025-recap-best-moments/",
#     "display_link": "https://www.billboard.com \u203a Music \u203a Music News",
#     "title": "10 Best Moments From REVOLVE Festival Weekend 2025",
#     "description": "Hosted at The Parker Hotel, the event doubled as a product launch ... DJ Pee .Wee Brought A Musical Oasis To The Red Bull Mirage At Coachella.",
#     "extensions": [
#       {
#         "inline": true,
#         "type": "text",
#         "text": "3 days ago",
#         "rank": 1
#       }
#     ],
#     "rank": 38,
#     "global_rank": 41
#   },
#   {
#     "link": "https://www.trendhunter.com/trends/second-cups-new-menu",
#     "display_link": "https://www.trendhunter.com \u203a second-cups-new-menu",
#     "title": "Seasonal Beverage Lineup Releases : Second Cup's new ...",
#     "description": "... Red Bull and coconut milk, pack a fruity punch. Starting April 15, these new drinks will be available nationwide for a limited time. Image ...",
#     "extensions": [
#       {
#         "inline": true,
#         "type": "text",
#         "text": "2 days ago",
#         "rank": 1
#       }
#     ],
#     "rank": 39,
#     "global_rank": 42
#   },
#   {
#     "link": "https://adage.com/influencers-creators/aa-creator-influencer-marketing-trends-revolve-818-tequila-true-religion-simply-pop/",
#     "display_link": "https://adage.com \u203a ... \u203a Food & Beverage \u203a Latest News",
#     "title": "Creator and influencer trends brand marketers need to know",
#     "description": "Dozens of brands, such as Neutrogena, Poppi, Red Bull and Alaska Airlines, flew influencers out to the California desert for the annual ...",
#     "extensions": [
#       {
#         "inline": true,
#         "type": "text",
#         "text": "3 days ago",
#         "rank": 1
#       }
#     ],
#     "rank": 40,
#     "global_rank": 43
#   },
#   {
#     "link": "https://www.marketscreener.com/quote/stock/REED-S-INC-59318310/news/Reed-s-Announces-Leadership-and-Board-Updates-49647391/",
#     "display_link": "https://www.marketscreener.com \u203a quote \u203a stock \u203a news",
#     "title": "Reed's Announces Leadership and Board Updates",
#     "description": "... beverage industry, including senior roles at Red Bull , Diageo and Heineken. ... launch and scale distinctive brands. He holds a Master of ...",
#     "extensions": [
#       {
#         "inline": true,
#         "type": "text",
#         "text": "1 day ago",
#         "rank": 1
#       }
#     ],
#     "rank": 41,
#     "global_rank": 44
#   },
#   {
#     "link": "https://www.cnn.com/",
#     "display_link": "https://www.cnn.com",
#     "title": "CNN: Breaking News, Latest News and Videos",
#     "description": "... Start and heating assistance targeted in Trump draft budget proposal ... Red Bull exit after turbulent start to season \u00b7 28-year-old former MLS player ...",
#     "rank": 42,
#     "global_rank": 45
#   },
#   {
#     "link": "https://communityimpact.com/news/austin/",
#     "display_link": "https://communityimpact.com \u203a news \u203a austin",
#     "title": "Austin Metro",
#     "description": "From Red Bull infusions to maple waffle sandwiches, the popular drive-thru ... BISD students launch careers with Acutronic \u00b7 By Amanda Cutshall. Bastrop ...",
#     "rank": 43,
#     "global_rank": 46
#   },
#   {
#     "link": "https://www.kfc.com.au/menu/drinks",
#     "display_link": "https://www.kfc.com.au \u203a menu \u203a drinks",
#     "title": "KFC Drinks Menu",
#     "description": "Start Order. Featured Offers; Everyday Value; Shared Meals; Boxed Meals; Chicken; Burgers; Twisters & Bowls; Snacks & Kids Meals; Sides; Drinks. Promos & ...",
#     "rank": 44,
#     "global_rank": 47
#   },
#   {
#     "link": "https://www.planet-vending.com/spiral-verdict-vendex-midlands-2025-product-review-drinks/",
#     "display_link": "https://www.planet-vending.com \u203a spiral-verdict-vendex-...",
#     "title": "Vendex Midlands 2025 \u2013 Product Review \u2013 Drinks",
#     "description": "... Red Bull. If you're looking for drinks that deliver on taste ... LinkedIn \u00b7 Twitter \u00b7 Tumblr \u00b7 Email. Like this: Like Loading... TagsPlanet ...",
#     "extensions": [
#       {
#         "inline": true,
#         "type": "text",
#         "text": "Apr 10, 2025",
#         "rank": 1
#       }
#     ],
#     "rank": 45,
#     "global_rank": 48
#   },
#   {
#     "link": "https://www.krqe.com/business/press-releases/cision/20250414CG63129/newmans-own-inc-kicks-off-pay-what-you-want-food-truck-tour-on-tax-day",
#     "display_link": "https://www.krqe.com \u203a business \u203a press-releases \u203a cision",
#     "title": "Newman's Own, Inc. Kicks Off \"Pay What You Want\" Food ...",
#     "description": "... Red Bull after Verstappen's 'catastrophe' \u2026 Mechanics push Red Bull ... Customers choose what they pay for Newman's Own food and drinks ...",
#     "extensions": [
#       {
#         "inline": true,
#         "type": "text",
#         "text": "4 days ago",
#         "rank": 1
#       }
#     ],
#     "rank": 46,
#     "global_rank": 49
#   },
#   {
#     "link": "https://timesofindia.indiatimes.com/sports/formula-one/news/yuki-tsunoda-believes-he-could-have-done-slightly-better-in-bahrain-despite-scoring-first-points/articleshow/120319355.cms",
#     "display_link": "https://timesofindia.indiatimes.com \u203a news \u203a articleshow",
#     "title": "Yuki Tsunoda believes he \u201ccould have done slightly better\u201d ...",
#     "description": "... start of the weekend,\u201d he wrote in the caption. Also Read: Max Verstappen on coming 6th at the Bahrain Grand Prix with Red Bull's balance ...",
#     "extensions": [
#       {
#         "inline": true,
#         "type": "text",
#         "text": "3 days ago",
#         "rank": 1
#       }
#     ],
#     "rank": 47,
#     "global_rank": 50
#   },
#   {
#     "link": "https://the-ken.com/podcasts/daybreak/scaler-wanted-to-do-for-tech-education-what-masters-union-did-for-the-mba-ai-had-other-plans/",
#     "display_link": "https://the-ken.com \u203a podcasts \u203a daybreak \u203a scaler-wante...",
#     "title": "Scaler wanted to do for tech education what Masters' Union ...",
#     "description": "Link Copied! Share on X Share on Linkedin Share on Whatsapp Share ... Red Bull is the energy drink of the world. How did Pepsico make ...",
#     "extensions": [
#       {
#         "inline": true,
#         "type": "text",
#         "text": "3 days ago",
#         "rank": 1
#       }
#     ],
#     "rank": 48,
#     "global_rank": 51
#   },
#   {
#     "link": "https://uk.linkedin.com/company/red-bull-racing",
#     "display_link": "961.3K+ followers",
#     "title": "Red Bull Racing & Red Bull Technology",
#     "description": "Website: http://www.redbullracing.com/. External link for Red Bull Racing & Red Bull Technology ; Industry: Spectator Sports ; Company size: 201-500 employees.",
#     "extensions": [
#       {
#         "type": "missing",
#         "text": "drinks",
#         "rank": 1
#       },
#       {
#         "type": "missing",
#         "text": "launch",
#         "rank": 2
#       }
#     ],
#     "rank": 49,
#     "global_rank": 52
#   }
# ]

# %%
len(news_data)
# Out:
# 50

# %%
# this works exactly like the playground
import requests

url = "https://api.brightdata.com/request"

payload = {
    "zone": "tccc_serp_api",
    "url": "https://www.google.com/search?q=redbull+launch&tbm=nws&brd_json=1",
    "format": "json",
    "method": "GET",
    # "country": "<string>"
}
headers = {
    "Authorization": "Bearer a7b67b30c2d03d7347d878e4871ed278d87bbb6e9695e73c30ca1a7fe84cb4ec",
    "Content-Type": "application/json"
}

response = requests.request("POST", url, json=payload, headers=headers)

print(response.json().get('body', ''))
# Out:
# {"general":{"search_engine":"google","query":"redbull launch","results_cnt":29500,"search_time":0.26,"language":"en-IN","country":"India","country_code":"IN","location":"India","gl":"IN","mobile":false,"basic_view":false,"search_type":"news","page_title":"redbull launch - Google Search","timestamp":"2025-04-18T10:25:52.463Z"},"input":{"original_url":"https://www.google.com/search?q=redbull+launch&tbm=nws&brd_json=1","request_id":"hl_ae0ae5cb_v51moiudcxd"},"navigation":[{"title":"All","href":"https://www.google.com/search?q=red+bull+launch&sca_esv=a39b70e8861fd680&hl=en&source=lnms&sa=X&ved=2ahUKEwjHu-CKr-GMAxWBFlkFHRaSGPIQ0pQJegQICBAD"},{"title":"Images","href":"https://www.google.com/search?q=red+bull+launch&sca_esv=a39b70e8861fd680&hl=en&udm=2&source=lnms&sa=X&ved=2ahUKEwjHu-CKr-GMAxWBFlkFHRaSGPIQ0pQJegQICBAF"},{"title":"Videos","href":"https://www.google.com/search?q=red+bull+launch&sca_esv=a39b70e8861fd680&hl=en&udm=7&source=lnms&sa=X&ved=2ahUKEwjHu-CKr-GMAxWBFlkFHRaSGPIQ0pQJegQICBAH"},{"title":"Shopping","href":"https://www.google.com/search?q=red+bull+launch&sca_esv=a39b70e8861fd680&hl=en&udm=28&source=lnms&ved=1t:200715&ictx=111"},{"title":"Books","href":"https://www.google.com/search?q=red+bull+launch&sca_esv=a39b70e8861fd680&hl=en&udm=36&source=lnms&sa=X&ved=2ahUKEwjHu-CKr-GMAxWBFlkFHRaSGPIQ0pQJegQICBAN"},{"title":"Maps","href":"https://maps.google.com/maps?hl=en&q=red+bull+launch&um=1&ie=UTF-8&ved=1t:200715&ictx=111"}],"news":[{"title":"FIA issues statement denouncing 'tribalist' booing of Max Verstappen and Christian Horner at F1 launch event","link":"https://sports.yahoo.com/f1/article/fia-issues-statement-denouncing-tribalist-booing-of-max-verstappen-and-christian-horner-at-f1-launch-event-191043033.html","source":"Yahoo Sports","source_logo":"...","description":"The FIA was so bothered by booing directed at Max Verstappen and Red Bull team principal Christian Horner this week that it issued a statement about the boos...","date":"6 hours ago","image":"data:image/jpeg;base64,...","image_base64":"data:image/jpeg;base64,...","rank":1,"global_rank":1},{"title":"“A great shame”: Yuki Tsunoda's Red Bull homecoming at Suzuka felt more like a lesson than a launch","link":"https://timesofindia.indiatimes.com/sports/formula-one/news/a-great-shame-yuki-tsunodas-red-bull-homecoming-at-suzuka-felt-more-like-a-lesson-than-a-launch/articleshow/120016974.cms","source":"Times of India","source_logo":"data:image/png;base64,...","description":"Formula One News: Yuki Tsunoda faced a challenging first home race for Red Bull at Suzuka, placing 14th after a penalty.","date":"2 weeks ago","image":"data:image/jpeg;base64,...","image_base64":"data:image/jpeg;base64,...","rank":2,"global_rank":2},{"title":"Red Bull gives important update on new Verstappen car launch","link":"https://racingnews365.com/red-bull-gives-important-update-on-new-verstappen-car-launch","source":"RacingNews365","source_logo":"data:image/png;base64,...","description":"Red Bull gives important update on new Verstappen car launch. The RB21 will be Red Bull's first-ever F1 car designed without the input of Adrian...","date":"11 Jan 2025","image":"data:image/jpeg;base64,...","image_base64":"data:image/jpeg;base64,...","rank":3,"global_rank":3},{"title":"Revealed: The new Oracle Red Bull Racing RB21","link":"https://www.redbull.com/int-en/oracle-red-bull-racing-2025-car-launch","source":"Red Bull","source_logo":"data:image/png;base64,...","description":"Red Bull Racing's RB21 was unveiled at F1's first global launch - with a bold design, plus big stakes and a championship battle ahead.","date":"18 Feb 2025","image":"data:image/jpeg;base64,...","image_base64":"data:image/jpeg;base64,...","rank":4,"global_rank":4},{"title":"Yuki Tsunoda unveils Venti Due, his fashion brand, ahead of his home race Suzuka GP debut with Red Bull","link":"https://www.indulgexpress.com/car-bike/formula-one/2025/Apr/01/yuki-tsunoda-unveils-venti-due-his-fashion-brand-ahead-of-his-home-race-suzuka ...

# %%
import json
print(json.dumps(response.json(), indent=2))
# Out:
# {
#   "status_code": 200,
#   "headers": {
#     "accept-ch": "Sec-CH-Prefers-Color-Scheme, Downlink, RTT, Sec-CH-UA-Form-Factors, Sec-CH-UA-Platform, Sec-CH-UA-Platform-Version, Sec-CH-UA-Full-Version, Sec-CH-UA-Arch, Sec-CH-UA-Model, Sec-CH-UA-Bitness, Sec-CH-UA-Full-Version-List, Sec-CH-UA-WoW64",
#     "alt-svc": "h3=\":443\"; ma=2592000,h3-29=\":443\"; ma=2592000",
#     "cache-control": "private, max-age=0",
#     "content-security-policy": "object-src 'none';base-uri 'self';script-src 'nonce-xf_9frgDqJj8JUHBlzXHXA' 'strict-dynamic' 'report-sample' 'unsafe-eval' 'unsafe-inline' https: http:;report-uri https://csp.withgoogle.com/csp/gws/other",
#     "content-type": "application/json",
#     "cross-origin-opener-policy": "same-origin-allow-popups; report-to=\"gws\"",
#     "date": "Fri, 18 Apr 2025 10:25:52 GMT",
#     "expires": "-1",
#     "p3p": "CP=\"This is not a P3P policy! See g.co/p3phelp for more info.\"",
#     "permissions-policy": "unload=()",
#     "report-to": "{\"group\":\"gws\",\"max_age\":2592000,\"endpoints\":[{\"url\":\"https://csp.withgoogle.com/csp/report-to/gws/other\"}]}",
#     "server": "gws",
#     "set-cookie": [
#       "AEC=AVcja2d9qVbHcPm7pncjmqCbx195_-OXTPI8BjzRSo180phB7_IUYuPJ_g; expires=Wed, 15-Oct-2025 10:25:52 GMT; path=/; domain=.google.com; Secure; HttpOnly; SameSite=lax",
#       "NID=523=SXBPxyzzD_rnvm8Uk4quDEh6-wXISrp56dO4pa3OksQQFOGJD_lZrfXLYXsqDIbYQhFbWSokv-9eRvyJY8WWnH5gRIAvwodA0CytwS55SgHb7GnO7N5tlVQeYjrcEvjseDr9D6uo3uf3OmZGa4myOF-8IFa85IOyysyt8uOJZZfEmlvFPzL9nxpOkPkbJJ3FEGe8pk_xrYty5E09Rm4eueuaB61Bs090O13UDz4-D91S8iY; expires=Sat, 18-Oct-2025 10:25:52 GMT; path=/; domain=.google.com; Secure; HttpOnly; SameSite=none"
#     ],
#     "strict-transport-security": "max-age=31536000",
#     "x-frame-options": "SAMEORIGIN",
#     "x-xss-protection": "0",
#     "x-unblocker-redirected-to": "https://www.google.com/search?q=redbull+launch&tbm=nws&hl=en",
#     "host": "unblocker-parser-f9dbcb7fc-8cf86",
#     "connection": "close",
#     "transfer-encoding": "chunked"
#   },
#   "body": "{\"general\":{\"search_engine\":\"google\",\"query\":\"redbull launch\",\"results_cnt\":29500,\"search_time\":0.26,\"language\":\"en-IN\",\"country\":\"India\",\"country_code\":\"IN\",\"location\":\"India\",\"gl\":\"IN\",\"mobile\":false,\"basic_view\":false,\"search_type\":\"news\",\"page_title\":\"redbull launch - Google Search\",\"timestamp\":\"2025-04-18T10:25:52.463Z\"},\"input\":{\"original_url\":\"https://www.google.com/search?q=redbull+launch&tbm=nws&brd_json=1\",\"request_id\":\"hl_ae0ae5cb_v51moiudcxd\"},\"navigation\":[{\"title\":\"All\",\"href\":\"https://www.google.com/search?q=red+bull+launch&sca_esv=a39b70e8861fd680&hl=en&source=lnms&sa=X&ved=2ahUKEwjHu-CKr-GMAxWBFlkFHRaSGPIQ0pQJegQICBAD\"},{\"title\":\"Images\",\"href\":\"https://www.google.com/search?q=red+bull+launch&sca_esv=a39b70e8861fd680&hl=en&udm=2&source=lnms&sa=X&ved=2ahUKEwjHu-CKr-GMAxWBFlkFHRaSGPIQ0pQJegQICBAF\"},{\"title\":\"Videos\",\"href\":\"https://www.google.com/search?q=red+bull+launch&sca_esv=a39b70e8861fd680&hl=en&udm=7&source=lnms&sa=X&ved=2ahUKEwjHu-CKr-GMAxWBFlkFHRaSGPIQ0pQJegQICBAH\"},{\"title\":\"Shopping\",\"href\":\"https://www.google.com/search?q=red+bull+launch&sca_esv=a39b70e8861fd680&hl=en&udm=28&source=lnms&ved=1t:200715&ictx=111\"},{\"title\":\"Books\",\"href\":\"https://www.google.com/search?q=red+bull+launch&sca_esv=a39b70e8861fd680&hl=en&udm=36&source=lnms&sa=X&ved=2ahUKEwjHu-CKr-GMAxWBFlkFHRaSGPIQ0pQJegQICBAN\"},{\"title\":\"Maps\",\"href\":\"https://maps.google.com/maps?hl=en&q=red+bull+launch&um=1&ie=UTF-8&ved=1t:200715&ictx=111\"}],\"news\":[{\"title\":\"FIA issues statement denouncing 'tribalist' booing of Max Verstappen and Christian Horner at F1 launch event\",\"link\":\"https://sports.yahoo.com/f1/article/fia-issues-statement-denouncing-tribalist-booing-of-max-verstappen-and-christian-horner-at-f1-launch-event-191043033.html\",\"source\":\"Yahoo Sports\",\"source_logo\":\"...\",\"description\":\"The FIA was so bothered by booing directed at Max Verstappen and Red Bull team principal Christian Horner this week that it issued a statement about the boos...\",\"date\":\"6 hours ago\",\"image\":\"data:image/jpeg;base64,...\",\"image_base64\":\"data:image/jpeg;base64,...\",\"rank\":1,\"global_rank\":1},{\"title\":\"\u201cA great shame\u201d: Yuki Tsunoda's Red Bull homecoming at Suzuka felt more like a lesson than a launch\",\"link\":\"https://timesofindia.indiatimes.com/sports/formula-one/news/a-great-shame-yuki-tsunodas-red-bull-homecoming-at-suzuka-felt-more-like-a-lesson-than-a-launch/articleshow/120016974.cms\",\"source\":\"Times of India\",\"source_logo\":\"data:image/png;base64,...\",\"description\":\"Formula One News: Yuki Tsunoda faced a challenging first home race for Red Bull at Suzuka, placing 14th after a penalty.\",\"date\":\"2 weeks ago\",\"image\":\"data:image/jpeg;base64,...\",\"image_base64\":\"data:image/jpeg;base64,...\",\"rank\":2,\"global_rank\":2},{\"title\":\"Red Bull gives important update on new Verstappen car launch\",\"link\":\"https://racingnews365.com/red-bull-gives-important-update-on-new-verstappen-car-launch\",\"source\":\"RacingNews365\",\"source_logo\":\"data:image/png;base64,...\",\"description\":\"Red Bull gives important update on new Verstappen car launch. The RB21 will be Red Bull's first-ever F1 car designed without the input of Adrian...\",\"date\":\"11 Jan 2025\",\"image\":\"data:image/jpeg;base64,...\",\"image_base64\":\"data:image/jpeg;base64,...\",\"rank\":3,\"global_rank\":3},{\"title\":\"Revealed: The new Oracle Red Bull Racing RB21\",\"link\":\"https://www.redbull.com/int-en/oracle-red-bull-racing-2025-car-launch\",\"source\":\"Red Bull\",\"source_logo\":\"data:image/png;base64,...\",\"description\":\"Red Bull Racing's RB21 was unveiled at F1's first global launch - with a bold design, plus big stakes and a championship battle ahead.\",\"date\":\"18 Feb 2025\",\"image\":\"data:image/jpeg;base64,...\",\"image_base64\":\"data:image/jpeg;base64,...\",\"rank\":4,\"glob ...
# }
