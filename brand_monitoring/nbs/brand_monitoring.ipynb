# %%
import urllib.request
import ssl

proxy = 'http://brd-customer-hl_d9bd517e-zone-bright_serp_cpg:7147z4kgj4r0@brd.superproxy.io:33335'
url = 'https://www.google.com/search?q=pizza'

opener = urllib.request.build_opener(
    urllib.request.ProxyHandler({'https': proxy, 'http': proxy}),
    urllib.request.HTTPSHandler(context=ssl._create_unverified_context())
)

try:
    print(opener.open(url).read().decode())
except Exception as e:
    print(f"Error: {e}")
# Out:
# Error: <urlopen error [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond>

# %%
import pprint
import requests


host = 'brd.superproxy.io'
port = 33335

username = 'brd-customer-hl_d9bd517e-zone-bright_serp_cpg'
password = '7147z4kgj4r0'

proxy_url = f'http://{username}:{password}@{host}:{port}'

proxies = {
    'http': proxy_url,
    'https': proxy_url
}


url = "https://www.google.com/search?q=pizza&brd_json=1"
response = requests.get(url, proxies=proxies, verify=False)
pprint.pprint(response.json())
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File C:\wns\AI_agents_hub\brand_monitoring\.venv\Lib\site-packages\urllib3\connectionpool.py:773, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     772 try:
# --> 773     self._prepare_proxy(conn)
#     774 except (BaseSSLError, OSError, SocketTimeout) as e:
#
# File C:\wns\AI_agents_hub\brand_monitoring\.venv\Lib\site-packages\urllib3\connectionpool.py:1042, in HTTPSConnectionPool._prepare_proxy(self, conn)
#    1036 conn.set_tunnel(
#    1037     scheme=tunnel_scheme,
#    1038     host=self._tunnel_host,
#    1039     port=self.port,
#    1040     headers=self.proxy_headers,
#    1041 )
# -> 1042 conn.connect()
#
# ...

# %%
#!/usr/bin/env python
print('If you get error "ImportError: No module named \'six\'" install six:\n'+\
    '$ sudo pip install six');
print('To enable your free eval account and get CUSTOMER, YOURZONE and ' + \
    'YOURPASS, please contact sales@brightdata.com')
import sys
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
if sys.version_info[0]==2:
    import six
    from six.moves.urllib import request
    opener = request.build_opener(
        request.ProxyHandler(
            {'http': 'http://brd-customer-hl_d9bd517e-zone-bright_serp_cpg:7147z4kgj4r0@brd.superproxy.io:33335',
            'https': 'http://brd-customer-hl_d9bd517e-zone-bright_serp_cpg:7147z4kgj4r0@brd.superproxy.io:33335'}))
    print(opener.open('https://www.google.com/search?q=pizza').read())
if sys.version_info[0]==3:
    import urllib.request
    opener = urllib.request.build_opener(
        urllib.request.ProxyHandler(
            {'http': 'http://brd-customer-hl_d9bd517e-zone-bright_serp_cpg:7147z4kgj4r0@brd.superproxy.io:33335',
            'https': 'http://brd-customer-hl_d9bd517e-zone-bright_serp_cpg:7147z4kgj4r0@brd.superproxy.io:33335'}))
    print(opener.open('https://www.google.com/search?q=pizza').read())
# Out:
# If you get error "ImportError: No module named 'six'" install six:
# $ sudo pip install six
# To enable your free eval account and get CUSTOMER, YOURZONE and YOURPASS, please contact sales@brightdata.com
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\AppData\Roaming\uv\python\cpython-3.12.1-windows-x86_64-none\Lib\urllib\request.py:1344, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1343 try:
# -> 1344     h.request(req.get_method(), req.selector, req.data, headers,
#    1345               encode_chunked=req.has_header('Transfer-encoding'))
#    1346 except OSError as err: # timeout error
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.1-windows-x86_64-none\Lib\http\client.py:1327, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1326 """Send a complete request to the server."""
# ...

# %%
import urllib.request
from urllib.error import URLError, HTTPError

# Define proxy credentials and target URL
proxy_credentials = 'http://brd-customer-hl_d9bd517e-zone-bright_serp_cpg:7147z4kgj4r0@brd.superproxy.io:33335'
proxies = {
    'http': proxy_credentials,
    'https': proxy_credentials
}
url = 'https://www.google.com/search?q=wns+analytics'

# Create an opener with proxy support
opener = urllib.request.build_opener(
    urllib.request.ProxyHandler(proxies)
)

# Add timeout and error handling
try:
    # Open the URL with a timeout of 10 seconds
    response = opener.open(url, timeout=10)
    print(response.read().decode('utf-8'))  # Decode the response content
except HTTPError as e:
    print(f"HTTP error occurred: {e.code} - {e.reason}")
except URLError as e:
    print(f"URL error occurred: {e.reason}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# URL error occurred: timed out

# %%
#!/usr/bin/env python

import sys
import urllib.request
import ssl

print('If you get error "ImportError: No module named \'six\'" install six:\n' + \
    '$ sudo pip install six\n\n')

#Bright Data Access
brd_user = 'hl_d9bd517e'
brd_zone = 'bright_serp_cpg'
brd_passwd = '7147z4kgj4r0'
brd_superpoxy = 'brd.superproxy.io:33335'
brd_connectStr = 'brd-customer-' + brd_user + '-zone-' + brd_zone + ':' + brd_passwd + '@' + brd_superpoxy

brd_test_url = 'https://www.google.com/search?q=pizza'

# Load the CA certificate file
ca_cert_path = r'C:\wns\AI_agents_hub\brand_monitoring\brightdata_proxy_ca\New SSL certifcate - MUST BE USED WITH PORT 33335\BrightData SSL certificate (port 33335).crt'
context = ssl.create_default_context(cafile=ca_cert_path)

if sys.version_info[0] == 2:
    import six
    from six.moves.urllib import request
    opener = request.build_opener(
        request.ProxyHandler(
            {'http': 'http://' + brd_connectStr,
            'https': 'https://' + brd_connectStr }),
        request.HTTPSHandler(context=context)
    )
    print(opener.open(brd_test_url).read())
elif sys.version_info[0] == 3:
    opener = urllib.request.build_opener(
        urllib.request.ProxyHandler(
            {'http': 'http://' + brd_connectStr,
            'https': 'https://' + brd_connectStr }),
        urllib.request.HTTPSHandler(context=context)
    )
    print(opener.open(brd_test_url).read().decode())
# Out:
# If you get error "ImportError: No module named 'six'" install six:
# $ sudo pip install six
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\AppData\Roaming\uv\python\cpython-3.12.1-windows-x86_64-none\Lib\urllib\request.py:1344, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1343 try:
# -> 1344     h.request(req.get_method(), req.selector, req.data, headers,
#    1345               encode_chunked=req.has_header('Transfer-encoding'))
#    1346 except OSError as err: # timeout error
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.1-windows-x86_64-none\Lib\http\client.py:1327, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1326 """Send a complete request to the server."""
# -> 1327 self._send_request(method, url, body, headers, encode_chunked)
#
# ...

# %%
import requests

url = "https://api.brightdata.com/request"
brd_test_url = 'https://www.google.com/search?q=sumanth_dhanya'
payload = {
    "zone": 'bright_serp_cpg',
    "url": brd_test_url,
    "format": "json",
    "method": "GET",
    "country": "IN"
}
headers = {
    "Authorization": "Bearer d3b76ac1a1eaf4c1797f8c1e8d4f505d09cb447603367f99e033cf8936e0255b",
    "Content-Type": "application/json"
}

response = requests.request("POST", url, json=payload, headers=headers)

# %%
response.json()['body']
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="hi"><head><meta charset="UTF-8"><meta content="origin" name="referrer"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>sumanth_dhanya - Google Search</title><script nonce="39po--WjE9Y9Gw0rwXRdZg">window._hst=Date.now();</script><script nonce="39po--WjE9Y9Gw0rwXRdZg">(function(){var b=window.addEventListener;window.addEventListener=function(a,c,d){a!=="unload"&&b(a,c,d)};}).call(this);(function(){var _g={kEI:\'OiH9Z_aCGeOHw8cPt6WfqQU\',kEXPI:\'31\',kBL:\'eaxO\',kOPI:89978449};(function(){var a;((a=window.google)==null?0:a.stvsc)?google.kEI=_g.kEI:window.google=_g;}).call(this);})();(function(){google.sn=\'web\';google.kHL=\'hi\';})();(function(){\nvar g=this||self;function k(){return window.google&&window.google.kOPI||null};var l,m=[];function n(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||l}function p(a
# ...

# %%
from bs4 import BeautifulSoup

# Parse HTML content with BeautifulSoup
soup = BeautifulSoup(response.json()['body'], "html.parser")

# Find all 'a' tags with 'href' attributes
links = [a['href'] for a in soup.find_all('a', href=True)]

# Output the extracted links
print("Extracted Links:", links)
# Out:
# Extracted Links: ['/httpservice/retry/enablejs?sei=OiH9Z_aCGeOHw8cPt6WfqQU', 'https://support.google.com/websearch/answer/181196?hl=hi', 'https://www.google.com/webhp?hl=hi&sa=X&ved=0ahUKEwj2h5ai49eMAxXjw_ACHbfSJ1UQPAgI', 'https://www.google.com/webhp?hl=hi&ictx=0&sa=X&ved=0ahUKEwj2h5ai49eMAxXjw_ACHbfSJ1UQpYkNCAo', 'https://www.google.com/intl/hi/about/products?tab=wh', 'https://accounts.google.com/ServiceLogin?hl=hi&passive=true&continue=https://www.google.com/search%3Fq%3Dsumanth_dhanya%26oq%3Dsumanth_dhanya%26gl%3Din%26uule%3Dw%2BCAIQICIFSW5kaWE%26hl%3Dhi%26sourceid%3Dchrome%26ie%3DUTF-8%26sei%3DLiH9Z7iBCYqa5OUP_PzvoAY&ec=GAZAAQ', '/search?sca_esv=ccd2c1cf7e06f38b&gl=in&hl=hi&q=sumanth+dhanya&udm=2&fbs=ABzOT_DZJpsdNgeoi6M15zjQF9iq04IwQsVPTA6xPFuAB25rqTAPcdYyh8NNuusAq_11PidIQO9zA7AaLxJE119Y1DMSX1XB_o9U86Bu83E_Rh93GJeVZ-LaUZlhvciyef4GDgo7OBWsDqMvI2Pr_9y1KL3iOK_TSJ1VCGluARwIDXmhI09zI-RgtT-_fVtOKsR32khAQNNtCTu95QcI1Ug4h9cyD-zSiSFVyj1mzfDPOmlJ7sr3r-2EhAC3eUyi_cfxXPKfTKNPe6Uw2IrXPyMnPua
# ...

# %%
|import requests

# Example URL (replace with the actual API endpoint)
url = "https://example.com/api"

# Send a GET request (modify the request method, headers, etc., if needed)
response = requests.get(url)

try:
    # Step 1: Ensure the response is not empty and has a status code of 200 (OK)
    if response.status_code != 200:
        raise ValueError(f"Error: Received status code {response.status_code}")

    # Step 2: Check if the content type is JSON
    if "application/json" not in response.headers.get("Content-Type", ""):
        raise ValueError("Error: Response content is not JSON")

    # Step 3: Try to parse the JSON content
    data = response.json()

    # Step 4: Safeguard against missing keys
    if 'organic' not in data:
        raise KeyError("'organic' key not found in the JSON response.")

    # Print the 'organic' data
    print(data['organic'])

except requests.exceptions.RequestException as e:
    print(f"HTTP Request failed: {e}")
except ValueError as ve:
    print(ve)
except KeyError as ke:
    print(ke)
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Error: Received status code 404

# %%
import re


def extract_links(response_text):
    """
    Extract all links (URLs) from a given text.

    :param response_text: The text to search for URLs.
    :return: A list of extracted URLs.
    """
    # Regular expression to match URLs
    url_regex = r'(https?://[^\s]+)'

    # Find all matches in the response text
    links = re.findall(url_regex, response_text)

    return links


# Example usage
response_text = """
Here are some links:
https://example.com
http://test.org/path?query=123
Contact us here: https://contact-us.site.
"""

extracted_links = extract_links(response.text)
print("Extracted links:", extracted_links)
# Out:
# Extracted links: ['http://schema.org/SearchResultsPage"', 'https://www.googleadservices.com/pagead/conversion/16521530460/?gad_source=1&adview_type=3";else', 'https://www.google.com/pagead/1p-conversion/16521530460/?gad_source=1&adview_type=5";else', 'https://www.googleadservices.com/pagead/aclk"+d.substring(e),method:a}}a!==null&&(a.method==="sendBeacon"?navigator.sendBeacon&&navigator.sendBeacon(a.url,""):a.method==="fetch"&&fetch(a.url,{method:"GET",keepalive:!0,credentials:"include",mode:"no-cors",redirect:"follow"}));a={i:this.g};a=(a===void', 'https://support.google.com/websearch/answer/181196?hl=hi"', 'https://support.google.com/websearch/answer/181196%3Fhl%3Dhi&amp;ved=0ahUKEwjy9oTW0NeMAxXbqZUCHf0SBDYQwcMDCAY&amp;opi=89978449">सुलभता', 'https://www.google.com.br/webhp?hl=hi&amp;sa=X&amp;ved=0ahUKEwjy9oTW0NeMAxXbqZUCHf0SBDYQPAgI"', 'http://www.w3.org/2000/svg"><path', 'https://www.google.com.br/webhp?hl=hi&amp;ictx=0&amp;sa=X&amp;ved=0ahUKEwjy9oTW0NeMAxXbqZUCHf0SBDYQpYkNCAo"',
# ...

# %%
import urllib.request
import ssl

proxy = 'http://brd-customer-hl_d9bd517e-zone-bright_serp_cpg:7147z4kgj4r0@brd.superproxy.io:33335'
url = 'http://www.google.com/search?q=pizza'

opener = urllib.request.build_opener(
    urllib.request.ProxyHandler({'https': proxy, 'http': proxy}),
    urllib.request.HTTPSHandler(context=ssl._create_unverified_context())
)

try:
    print(opener.open(url).read().decode())
except Exception as e:
    print(f"Error: {e}")

# jdbc:sqlserver://syn-tccc-bfa-use2-dev-01.sql.azuresynapse.net:1433;database=sqldwbfadev01;user={your_username_here};password={your_password_here};encrypt=true;trustServerCertificate=false;hostNameInCertificate=*.sql.azuresynapse.net;loginTimeout=30;authentication=ActiveDirectoryPassword
# Out:
# Error: [WinError 10054] An existing connection was forcibly closed by the remote host

# %%
import requests

proxy = 'http://brd-customer-hl_d9bd517e-zone-bright_serp_cpg:7147z4kgj4r0@brd.superproxy.io:33335'
url = 'http://www.google.com/search?q=pizza'

proxies = {
    'http': proxy,
    'https': proxy,
}

try:
    response = requests.get(url, proxies=proxies, verify=False)
    print(response.text)
except requests.exceptions.RequestException as e:
    print(e)
# Out:
# HTTPConnectionPool(host='brd.superproxy.io', port=33335): Max retries exceeded with url: http://www.google.com/search?q=pizza (Caused by ProxyError('Unable to connect to proxy', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)))

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36'
}

# Missing closing parenthesis here:
page = requests.get('https://quotes.toscrape.com', headers=headers)

# %%
page
# Out:
# <Response [200]>

# %%
import requests
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
quotes = []

# %%
quote_elements = soup.find_all('div', class_='quote')

# %%
for quote_element in quote_elements:
    # extract the text of the quote
    text = quote_element.find('span', class_='text').text
    # extract the author of the quote
    author = quote_element.find('small', class_='author').text

    # extract the tag <a> HTML elements related to the quote
    tag_elements = quote_element.select('.tags .tag')

    # store the list of tag strings in a list
    tags = []
    for tag_element in tag_elements:
        tags.append(tag_element.text)

# %%
tags
# Out:
# ['books', 'mind']

# %%
quotes.append(
    {
        'text': text,
        'author': author,
        'tags': ', '.join(tags) # merge the tags into a "A, B, ..., Z" string
    }
)

# %%
# the URL of the home page of the target website
base_url = 'https://quotes.toscrape.com'

# retrieve the page and initializing soup...

# get the "Next →" HTML element
next_li_element = soup.find('li', class_='next')

# if there is a next page to scrape
while next_li_element is not None:
    next_page_relative_url = next_li_element.find('a', href=True)['href']

    # get the new page
    page = requests.get(base_url + next_page_relative_url, headers=headers)

    # parse the new page
    soup = BeautifulSoup(page.text, 'html.parser')

    # scraping logic...

    # look for the "Next →" HTML element in the new page
    next_li_element = soup.find('li', class_='next')

# %%
import csv

# scraping logic...

# reading  the "quotes.csv" file and creating it
# if not present
with open('quotes.csv', 'w', encoding='utf-8', newline='') as csv_file:
	# initializing the writer object to insert data
	# in the CSV file
	writer = csv.writer(csv_file)

	# writing the header of the CSV file
	writer.writerow(['Text', 'Author', 'Tags'])

	# writing each row of the CSV
	for quote in quotes:
	    writer.writerow(quote.values())

# terminating the operation and releasing the resources
csv_file.close()

# %%
import urllib.request
response = urllib.request.urlopen('http://example.com', timeout=10)
response

# %%
import urllib.request

proxy_support = urllib.request.ProxyHandler({
   'http': 'http://hl_d9bd517e:7147z4kgj4r0@brd.superproxy.io:33335',
   'https': 'http://hl_d9bd517e:7147z4kgj4r0@brd.superproxy.io:33335'
})
opener = urllib.request.build_opener(proxy_support)

urllib.request.install_opener(opener)

response = urllib.request.urlopen('http://example.com', timeout=10)
print(response.read())
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[4], line 11
#       7 opener = urllib.request.build_opener(proxy_support)
#       9 urllib.request.install_opener(opener)
# ---> 11 response = urllib.request.urlopen('http://example.com', timeout=10)
#      12 print(response.read())
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.1-windows-x86_64-none\Lib\urllib\request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.1-windows-x86_64-none\Lib\urllib\request.py:515, in OpenerDirector.open(self, fullurl, data, timeout)
#     512     req = meth(req)
#     514 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 515 response = self._open(req, data)
# ...

# %%
import urllib.request
import ssl

proxy = 'http://brd-customer-hl_d9bd517e-zone-bright_serp_cpg:7147z4kgj4r0@brd.superproxy.io:33335'
url = 'https://www.google.com/search?q=pizza'

opener = urllib.request.build_opener(
    urllib.request.ProxyHandler({'https': proxy, 'http': proxy}),
    urllib.request.HTTPSHandler(context=ssl._create_unverified_context())
)

try:
    print(opener.open(url).read().decode())
except Exception as e:
    print(f"Error: {e}")
# Out:
# Error: <urlopen error [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond>

# %%
#!/usr/bin/env python
print('If you get error "ImportError: No module named \'six\'" install six:\n'+\
    '$ sudo pip install six');
print('To enable your free eval account and get CUSTOMER, YOURZONE and ' + \
    'YOURPASS, please contact sales@brightdata.com')
import sys
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
if sys.version_info[0]==2:
    import six
    from six.moves.urllib import request
    opener = request.build_opener(
        request.ProxyHandler(
            {'http': 'http://brd-customer-hl_d9bd517e-zone-bright_serp_cpg:7147z4kgj4r0@brd.superproxy.io:33335',
            'https': 'http://brd-customer-hl_d9bd517e-zone-bright_serp_cpg:7147z4kgj4r0@brd.superproxy.io:33335'}))
    print(opener.open('https://www.google.com/search?q=pizza').read())
if sys.version_info[0]==3:
    import urllib.request
    opener = urllib.request.build_opener(
        urllib.request.ProxyHandler(
            {'http': 'http://brd-customer-hl_d9bd517e-zone-bright_serp_cpg:7147z4kgj4r0@brd.superproxy.io:33335',
            'https': 'http://brd-customer-hl_d9bd517e-zone-bright_serp_cpg:7147z4kgj4r0@brd.superproxy.io:33335'}))
    print(opener.open('https://www.google.com/search?q=pizza').read())
# Out:
# If you get error "ImportError: No module named 'six'" install six:
# $ sudo pip install six
# To enable your free eval account and get CUSTOMER, YOURZONE and YOURPASS, please contact sales@brightdata.com
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\AppData\Roaming\uv\python\cpython-3.12.1-windows-x86_64-none\Lib\urllib\request.py:1344, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1343 try:
# -> 1344     h.request(req.get_method(), req.selector, req.data, headers,
#    1345               encode_chunked=req.has_header('Transfer-encoding'))
#    1346 except OSError as err: # timeout error
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.1-windows-x86_64-none\Lib\http\client.py:1327, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1326 """Send a complete request to the server."""
# ...

# %%
#!/usr/bin/env python
print('If you get error "ImportError: No module named \'six\'" install six:\n'+\
    '$ sudo pip install six');
print('To enable your free eval account and get CUSTOMER, YOURZONE and ' + \
    'YOURPASS, please contact sales@brightdata.com')
import sys
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
if sys.version_info[0]==2:
    import six
    from six.moves.urllib import request
    opener = request.build_opener(
        request.ProxyHandler(
            {'http': 'http://brd-customer-hl_d9bd517e-zone-bright_serp_cpg:7147z4kgj4r0@brd.superproxy.io:33335',
            'https': 'http://brd-customer-hl_d9bd517e-zone-bright_serp_cpg:7147z4kgj4r0@brd.superproxy.io:33335'}))
    print(opener.open('https://www.google.com/search?q=wns+analytics&location=France&uule=w+CAIQICIGRnJhbmNl').read())
if sys.version_info[0]==3:
    import urllib.request
    opener = urllib.request.build_opener(
        urllib.request.ProxyHandler(
            {'http': 'http://brd-customer-hl_d9bd517e-zone-bright_serp_cpg:7147z4kgj4r0@brd.superproxy.io:33335',
            'https': 'http://brd-customer-hl_d9bd517e-zone-bright_serp_cpg:7147z4kgj4r0@brd.superproxy.io:33335'}))
    print(opener.open('https://www.google.com/search?q=wns+analytics&location=France&uule=w+CAIQICIGRnJhbmNl').read())
# Out:
# If you get error "ImportError: No module named 'six'" install six:
# $ sudo pip install six
# To enable your free eval account and get CUSTOMER, YOURZONE and YOURPASS, please contact sales@brightdata.com
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\AppData\Roaming\uv\python\cpython-3.12.1-windows-x86_64-none\Lib\urllib\request.py:1344, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1343 try:
# -> 1344     h.request(req.get_method(), req.selector, req.data, headers,
#    1345               encode_chunked=req.has_header('Transfer-encoding'))
#    1346 except OSError as err: # timeout error
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.1-windows-x86_64-none\Lib\http\client.py:1327, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1326 """Send a complete request to the server."""
# ...
